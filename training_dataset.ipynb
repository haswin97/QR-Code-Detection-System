# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/TA_2
# Out:
# /content/drive/My Drive/TA_2

# %%
# !pip install tensorflow-gpu==1.14
# Out:
# ...
#      |████████████████████████████████| 377.0MB 42kB/s
# ...
#      |████████████████████████████████| 491kB 21.7MB/s
# ...
#      |████████████████████████████████| 3.2MB 30.4MB/s
# ...
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 1.14.0 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 1.14.0 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
# ...

# %%
# !pip install tensorflow==1.14

# %%
pip install git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# ...
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-g45phlvq
#   Running command git clone -q https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-g45phlvq
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp36-cp36m-linux_x86_64.whl size=275431 sha256=9aa9fd652fa57023c98d3e9008561e56e4a0ee96a4ba5dd10d4bc496bb6472e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e1r0t83s/wheels/69/2b/12/2fa959e49f73d26cff202c2f4e5079096c9c57c8a8509fd75c
# Successfully built pycocotools

# %%
# !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 32462, done.
# remote: Total 32462 (delta 0), reused 0 (delta 0), pack-reused 32462
# Receiving objects: 100% (32462/32462), 511.71 MiB | 15.30 MiB/s, done.
# Resolving deltas: 100% (20763/20763), done.
# Checking out files: 100% (2487/2487), done.

# %%
# %cd /content/drive/My Drive/TA_2/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/My Drive/TA_2/models/research

# %%
! echo $PYTHONPATH

import os
os.environ['PYTHONPATH'] += ":/content/drive/My Drive/TA_2/models/research"
os.environ['PYTHONPATH'] += ":/content/drive/My Drive/TA_2/models/research/slim"
os.environ['PYTHONPATH'] += ":/content/drive/My Drive/TA_2/models/research/object_detection"

! echo $PYTHONPATH
# Out:
# /env/python
# /env/python:/content/drive/My Drive/TA_2/models/research:/content/drive/My Drive/TA_2/models/research/slim:/content/drive/My Drive/TA_2/models/research/object_detection

# %%
! echo $PATH

import os
os.environ['PATH'] += ":/content/drive/My Drive/TA_2/models/research/object_detection"

! echo $PATH
# Out:
# /usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin
# /usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin:/content/drive/My Drive/TA_2/models/research/object_detection

# %%
# %cd /content/drive/My Drive/TA_2/workspace/training_demo
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_resnet50_coco.config
# Out:
# Streaming output truncated to the last 5000 lines.
# I0312 15:30:36.816886 140050344822656 learning.py:507] global step 27073: loss = 0.0102 (0.191 sec/step)
# INFO:tensorflow:global step 27074: loss = 0.0597 (0.191 sec/step)
# I0312 15:30:37.009730 140050344822656 learning.py:507] global step 27074: loss = 0.0597 (0.191 sec/step)
# INFO:tensorflow:global step 27075: loss = 0.0082 (0.176 sec/step)
# I0312 15:30:37.187396 140050344822656 learning.py:507] global step 27075: loss = 0.0082 (0.176 sec/step)
# INFO:tensorflow:global step 27076: loss = 0.0119 (0.201 sec/step)
# I0312 15:30:37.390075 140050344822656 learning.py:507] global step 27076: loss = 0.0119 (0.201 sec/step)
# INFO:tensorflow:global step 27077: loss = 0.0126 (0.199 sec/step)
# I0312 15:30:37.591663 140050344822656 learning.py:507] global step 27077: loss = 0.0126 (0.199 sec/step)
# INFO:tensorflow:global step 27078: loss = 0.0068 (0.217 sec/step)
# ...
